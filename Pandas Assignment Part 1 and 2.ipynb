# %% [markdown]
# # Pandas Asignment 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('./states0.csv')

# %%
df2=pd.read_csv('./states1.csv')

# %%
df3=pd.read_csv('./states2.csv')

# %%
df4=pd.read_csv('./states3.csv')

# %%
df5=pd.read_csv('./states4.csv')

# %%
df6=pd.read_csv('./states5.csv')

# %%
df7=pd.read_csv('./states6.csv')

# %%
df8=pd.read_csv('./states7.csv')

# %%
df9=pd.read_csv('./states8.csv')

# %%
df10=pd.read_csv('./states9.csv')

# %%
df1.head(5)
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
df2.head(5)
# Out:
#    Unnamed: 0                 State  TotalPop             Hispanic  \
# 0           0              Colorado   5278906   20.78438003220608%
# 1           1           Connecticut   3593222  15.604830917874388%
# 2           2              Delaware    926454    8.82476635514019%
# 3           3  District of Columbia    647484   9.165921787709499%
# 4           4               Florida  19645772    21.3385426653884%
#
#                  White                Black                Native  \
# 0   69.89557165861504%   3.546376811594201%   0.5738325281803548%
# 1    67.6770531400966%   10.34806763285027%  0.12620772946859898%
# 2   64.63271028037383%  20.743925233644834%  0.25981308411214965%
# 3  33.103910614525134%   51.77653631284915%  0.20055865921787713%
# 4   59.08374880153398%  15.165675934803444%   0.2104506232023015%
#
#                  Asian                Pacific               Income  \
# 0   2.661996779388082%                    NaN  $64657.801787164906
# ...

# %%
df3.head()
# Out:
#    Unnamed: 0     State  TotalPop             Hispanic                White  \
# 0           0   Georgia  10006693   8.418242207460397%   54.28630556974962%
# 1           1    Hawaii   1406299   9.186708860759486%  25.032278481012657%
# 2           2     Idaho   1616547  11.505369127516781%    83.1362416107383%
# 3           3  Illinois  12873761  15.601733547351516%   60.85980738362764%
# 4           4   Indiana   6568645   6.536744186046501%   78.43189368770771%
#
#                  Black                Native                Asian  \
# 0   32.08829841594277%  0.18758303525804798%  3.0976494634644895%
# 1   2.052848101265823%   0.1449367088607596%   36.59208860759495%
# 2  0.5667785234899323%    1.468120805369128%   1.135906040268457%
# 3  17.108410914927717%  0.11842696629213499%   4.475377207062604%
# 4   11.18697674418606%   0.1940863787375415%  1.5782724252491687%
#
#                  Pacific              Income          GenderPop
# ...

# %%
us_census=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9], ignore_index=True)
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            5              Colorado   5278906   20.78438003220608%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.drop(columns = ['Unnamed: 0'], inplace = True)
us_census
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0                Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1                 Alaska    733375   5.909580838323351%  60.910179640718574%
# 2                Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3               Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4             California  38421464  37.291874687968054%   40.21578881677474%
# 5               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 6               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 7            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 8               Delaware    926454    8.82476635514019%   64.63271028037383%
# 9   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 10               Florida  19645772    21.3385426653884%   59.08374880153398%
# ...

# %%
us_census[['Male','Female']] = us_census.GenderPop.str.split("_",expand=True)

# %%
us_census.drop(columns = ['GenderPop'], inplace=True)

# %%
us_census['Income'] = us_census.Income.str.strip('$')

# %%
us_census = us_census.replace('%','', regex=True)

# %%
us_census = us_census.replace('F','', regex=True)

# %%
us_census = us_census.replace('M','', regex=True)

# %%
us_census.loc[:,'Hispanic':'Income'] = round(us_census.loc[:,'Hispanic':'Income'].apply(pd.to_numeric),2)

# %%
us_census['Male'] = us_census['Male'].astype(int)

# %%
us_census.drop(columns = ['Female'], inplace=True)

# %%
us_census['Female'] = us_census['TotalPop'] - us_census['Male']

# %%
us_census.drop_duplicates(subset = ['State'])
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0                Alabama   4830620      3.75  61.88  31.25    0.45   1.05
# 1                 Alaska    733375      5.91  60.91   2.85   16.39   5.45
# 2                Arizona   6641928     29.57  57.12   3.85    4.36   2.88
# 3               Arkansas   2958208      6.22  71.14  18.97    0.52   1.14
# 4             California  38421464     37.29  40.22   5.68    0.41  13.05
# 5               Colorado   5278906     20.78  69.90   3.55    0.57   2.66
# 7            Connecticut   3593222     15.60  67.68  10.35    0.13   4.02
# 8               Delaware    926454      8.82  64.63  20.74    0.26   3.27
# 9   District of Columbia    647484      9.17  33.10  51.78    0.20   3.38
# 10                lorida  19645772     21.34  59.08  15.17    0.21   2.28
# 11               Georgia  10006693      8.42  54.29  32.09    0.19   3.10
# 13                Hawaii   1406299      9.19  25.03   2.05    0.14  36.59
# ...

# %%
us_census.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic    float64
# White       float64
# Black       float64
# Native      float64
# Asian       float64
# Pacific     float64
# Income      float64
# Male          int32
# Female        int64
# dtype: object

# %%
plt.scatter(us_census['Female'],us_census['Income'])
plt.xlabel('Salary $', fontsize=18)
plt.ylabel('Female_Population', fontsize=16)
plt.show()

# %%
plt.scatter(us_census['Female'],us_census['Income'])
plt.xlabel('Salary $', fontsize=18)
plt.ylabel('Female_Population', fontsize=16)
plt.show()

# %%
us_census.describe()
# Out:
#            TotalPop   Hispanic      White      Black     Native      Asian  \
# count  5.400000e+01  54.000000  54.000000  54.000000  54.000000  54.000000
# mean   6.443432e+06  12.946481  66.255741  12.829259   1.447593   3.639630
# std    6.857132e+06  15.267294  17.634974  11.983635   3.037167   5.152159
# min    6.474840e+05   1.430000   0.770000   0.090000   0.000000   0.080000
# 25%    2.262747e+06   4.757500  56.475000   3.332500   0.190000   1.590000
# 50%    4.701414e+06   8.470000  69.900000   9.330000   0.350000   2.325000
# 75%    8.354706e+06  15.067500  78.177500  17.500000   0.842500   3.650000
# max    3.842146e+07  98.890000  93.710000  51.780000  16.390000  36.590000
#
#          Pacific        Income          Male        Female
# count  49.000000     54.000000  5.400000e+01  5.400000e+01
# mean    0.286122  56409.905556  3.165738e+06  3.277694e+06
# std     1.252224  11614.027997  3.383980e+06  3.473708e+06
# ...

# %%
histogram =  round(us_census.loc[:,'Hispanic':'Pacific'].apply(lambda x:x*us_census['TotalPop']/100))

# %%
histogram.head()
# Out:
#      Hispanic       White      Black    Native      Asian   Pacific
# 0    181148.0   2989188.0  1509569.0   21738.0    50722.0    1449.0
# 1     43342.0    446699.0    20901.0  120200.0    39969.0    7774.0
# 2   1964018.0   3793869.0   255714.0  289588.0   191288.0   11291.0
# 3    184001.0   2104469.0   561172.0   15383.0    33724.0    4437.0
# 4  14327364.0  15453113.0  2182339.0  157528.0  5014001.0  134475.0

# %%
histogram['total_pop'] =us_census['TotalPop']
histogram['state'] = us_census['State']

# %%
histogram.hist(column='Hispanic')
# Out:
# array([[<AxesSubplot:title={'center':'Hispanic'}>]], dtype=object)

# %%
histogram.hist(column='White')
# Out:
# array([[<AxesSubplot:title={'center':'White'}>]], dtype=object)

# %%
histogram.hist(column='Black')
# Out:
# array([[<AxesSubplot:title={'center':'Black'}>]], dtype=object)

# %%
histogram.hist(column='Native')
# Out:
# array([[<AxesSubplot:title={'center':'Native'}>]], dtype=object)

# %%
histogram.hist(column='Asian')
# Out:
# array([[<AxesSubplot:title={'center':'Asian'}>]], dtype=object)

# %% [markdown]
# # Assignment Part 2

# %%
inventory = pd.read_csv('./inventory.csv')

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   location             29 non-null     object
#  1   product_type         29 non-null     object
#  2   product_description  29 non-null     object
#  3   quantity             29 non-null     int64
#  4   price                29 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.3+ KB

# %%
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
staten_island = inventory.head(10)
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
product_request = staten_island['product_description']
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
staten_island.columns
# Out:
# Index(['location', 'product_type', 'product_description', 'quantity', 'price'], dtype='object')

# %%
seed=inventory[inventory['location'] == 'Brooklyn']
seed
# Out:
#     location  product_type         product_description  quantity  price
# 10  Brooklyn         seeds                       daisy        50   6.99
# 11  Brooklyn         seeds                  calla lily         0  19.99
# 12  Brooklyn         seeds                      tomato         0  13.99
# 13  Brooklyn  garden tools                        rake        15  13.99
# 14  Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15  Brooklyn  garden tools                       spade        36  19.99
# 16  Brooklyn  pest_control               insect killer        80  12.99
# 17  Brooklyn  pest_control                 weed killer        76  23.99
# 18  Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19  Brooklyn       planter      8 inch plastic planter        26   3.99

# %%
seed_request = seed[seed['product_type']=='seeds']
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
inventory['in_stock'] = inventory['quantity']>0
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
inventory['total_value'] = inventory['quantity'] * inventory['price']
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type,
                     row.product_description)

# %%
inventory['full_description'] = inventory.apply(combine_lambda, axis = 1)
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
inventory['full_description']
# Out:
# 0                            seeds - daisy
# 1                       seeds - calla lily
# 2                           seeds - tomato
# 3                      garden tools - rake
# 4               garden tools - wheelbarrow
# 5                     garden tools - spade
# 6             pest_control - insect killer
# 7               pest_control - weed killer
# 8     planter - 20 inch terracotta planter
# 9         planter - 8 inch plastic planter
# 10                           seeds - daisy
# 11                      seeds - calla lily
# 12                          seeds - tomato
# 13                     garden tools - rake
# 14              garden tools - wheelbarrow
# 15                    garden tools - spade
# 16            pest_control - insect killer
# 17              pest_control - weed killer
# 18    planter - 20 inch terracotta planter
# 19        planter - 8 inch plastic planter
# 20                           seeds - daisy
# 21                      seeds - calla lily
# ...
